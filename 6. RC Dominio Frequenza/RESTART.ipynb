# %%
# %%capture
# %run "/home/nichettg/Ubuntu/Laboratorio/6. RC Dominio Frequenza/conversione.ipynb"
# %run "/home/nichettg/Ubuntu/Laboratorio/6. RC Dominio Frequenza/bode.ipynb"

for conf in [True,False]:
    confronto = conf
    # %run "/home/nichettg/Ubuntu/Laboratorio/6. RC Dominio Frequenza/linearizzato.ipynb"
    for nonlin in [True,False]:
        nonlineare = nonlin
        # %run "/home/nichettg/Ubuntu/Laboratorio/6. RC Dominio Frequenza/nonlineare.ipynb"

# %run "/home/nichettg/Ubuntu/Laboratorio/6. RC Dominio Frequenza/confronto.ipynb"
