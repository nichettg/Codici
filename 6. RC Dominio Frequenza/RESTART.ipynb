# %%
# %%capture
# %run "./conversione.ipynb"
# %run "./bode.ipynb"

for conf in [True,False]:
    confronto = conf
    # %run "./linearizzato.ipynb"
    for nonlin in [True,False]:
        nonlineare = nonlin
        # %run "./nonlineare.ipynb"

# %run "./confronto.ipynb"
