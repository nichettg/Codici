# %%
# %run "/home/nichettg/Ubuntu/Laboratorio/moduli.py"

# %% [markdown]
# # Lettura Dati

# %%
keys = ["locale", "nonlineare", "bode", "linearizzato"]

# %%
bode = let.importa_pickle("bode.pkl")
locale = let.importa_pickle("locale.pkl")
nonlineare = let.importa_pickle("nonlineare.pkl")
linearizzato = let.importa_pickle("linearizzato.pkl")

dizionario_ris_fit = {}
for key in keys:
    dizionario_ris_fit[key] = let.importa_pickle(f"{key}.pkl")

# %%
gf.display_dizionario(dizionario_ris_fit)
# Out:
# <table border="1" style="border-collapse: collapse;"><tr><td><strong>locale</strong></td><td><table border="1" style="border-collapse: collapse;"><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;<strong>A</strong></td><td><table border="1" style="border-collapse: collapse;"><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[ 1.05383307e+00 -6.26336800e-05]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>s_parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[2.99721859e-02 5.32075369e-06]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>res</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0.002081857919140062</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0.35258461749790837</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi_ridotto</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0.05876410291631806</td></tr></table></td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;<strong>phi</strong></td><td><table border="1" style="border-collapse: collapse;"><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[0.05737979 0.00014543]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>s_parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[1.42908503e-02 6.24442774e-06]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>res</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;-0.16540179985122322</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;21.948734467681806</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi_ridotto</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3.658122411280301</td></tr></table></td></tr></table></td></tr><tr><td><strong>nonlineare</strong></td><td><table border="1" style="border-collapse: collapse;"><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;<strong>A</strong></td><td><table border="1" style="border-collapse: collapse;"><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[5.47199380e+03 1.29119054e+02 3.87127621e-03]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>s_parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[1.28713955e+02 1.24482461e+02 7.87693253e-03]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>res</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;-0.010957986515235357</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0.10547133026267091</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi_ridotto</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0.006204195897804171</td></tr></table></td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;<strong>phi</strong></td><td><table border="1" style="border-collapse: collapse;"><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[ 5.60099488e+03 -3.49669293e+01  1.26697818e-04]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>s_parametri</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[0.15931596 0.04080478 0.00209261]</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>res</strong></td><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0.6713894816509548</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>chi</strong></td><td>&nbsp;&nbs ...

# %% [markdown]
# # Stampa Test Statistici

# %%
let.inizializza_output("confronto.txt")

with open("confronto.txt", "a") as file:
    file.write("#######################\n")
    file.write("###### Locale\n")
    file.write("#######################\n")

    file.write("A\n")
    file.write(str(let.dict_to_ris_fit(locale["A"])) + "\n")

    file.write("phi\n")
    file.write(str(let.dict_to_ris_fit(locale["phi"])) + "\n")

    file.write("#######################\n")
    file.write("###### Non Lineare\n")
    file.write("#######################\n")

    file.write("A\n")
    file.write(str(let.dict_to_ris_fit(nonlineare["A"])) + "\n")

    file.write("phi\n")
    file.write(str(let.dict_to_ris_fit(nonlineare["phi"])) + "\n")

    file.write("#######################\n")
    file.write("###### Bode\n")
    file.write("#######################\n")

    file.write(str(let.dict_to_ris_fit(bode)) + "\n")

    file.write("#######################\n")
    file.write("###### Linearizzato\n")
    file.write("#######################\n")

    file.write("A\n")
    file.write(str(let.dict_to_ris_fit(linearizzato["A"])) + "\n")

    file.write("phi\n")
    file.write(str(let.dict_to_ris_fit(linearizzato["phi"])) + "\n")

# %% [markdown]
# # Dizionario Confronto Stime $f_t$.

# %%
dizionario_f_taglio = {}
dizionario_chi = {}

# Locale
key = "locale"
tipo = "A"
c = dizionario_ris_fit[key][tipo]["parametri"][0]
sigma_c = dizionario_ris_fit[key][tipo]["s_parametri"][0]
m = dizionario_ris_fit[key][tipo]["parametri"][1]
sigma_m = dizionario_ris_fit[key][tipo]["s_parametri"][1]
dizionario_f_taglio[f"{key}_{tipo}"] = Misura(
    ( 1/np.sqrt(2) - c) / m,
    np.sqrt((sigma_c / m)**2 + ((1/np.sqrt(2) - c) / (m**2) * sigma_m)**2)
)
dizionario_chi[f"{key}_{tipo}"] = dizionario_ris_fit[key][tipo]["chi_ridotto"]
tipo = "phi"
c = dizionario_ris_fit[key][tipo]["parametri"][0]
sigma_c = dizionario_ris_fit[key][tipo]["s_parametri"][0]
m = dizionario_ris_fit[key][tipo]["parametri"][1]
sigma_m = dizionario_ris_fit[key][tipo]["s_parametri"][1]
dizionario_f_taglio[f"{key}_{tipo}"] = Misura(
    ( 1/2 - c) / m,
    np.sqrt((sigma_c / m)**2 + ((1/2 - c) / (m**2) * sigma_m)**2)
)
dizionario_chi[f"{key}_{tipo}"] = dizionario_ris_fit[key][tipo]["chi_ridotto"]

# Non Lineare
key = "nonlineare"
for tipo in ["A","phi"]:
    dizionario_f_taglio[f"{key}_{tipo}"] = Misura(
        dizionario_ris_fit[key][tipo]["parametri"][0],
        dizionario_ris_fit[key][tipo]["s_parametri"][0],
    )
    dizionario_chi[f"{key}_{tipo}"] = dizionario_ris_fit[key][tipo]["chi_ridotto"]

# Bode
dizionario_f_taglio["bode"] = Misura(
    dizionario_ris_fit["bode"]["parametri"][0],
    dizionario_ris_fit["bode"]["s_parametri"][0]
)
dizionario_chi["bode"] = dizionario_ris_fit["bode"]["chi_ridotto"]

# Lineare
key = "linearizzato"
tipo = "A"
c = dizionario_ris_fit[key][tipo]["parametri"][0]
sigma_c = dizionario_ris_fit[key][tipo]["s_parametri"][0]
m = dizionario_ris_fit[key][tipo]["parametri"][1]
sigma_m = dizionario_ris_fit[key][tipo]["s_parametri"][1]
dizionario_f_taglio[f"{key}_{tipo}"] = Misura(
    1 / m,
    sigma_m / m**2
)
dizionario_chi[f"{key}_{tipo}"] = dizionario_ris_fit[key][tipo]["chi_ridotto"]
tipo = "phi"
c = dizionario_ris_fit[key][tipo]["parametri"][0]
sigma_c = dizionario_ris_fit[key][tipo]["s_parametri"][0]
m = dizionario_ris_fit[key][tipo]["parametri"][1]
sigma_m = dizionario_ris_fit[key][tipo]["s_parametri"][1]
dizionario_f_taglio[f"{key}_{tipo}"] = Misura(
    -1 / m,
    sigma_m / m**2
)
dizionario_chi[f"{key}_{tipo}"] = dizionario_ris_fit[key][tipo]["chi_ridotto"]

# %%
print("Stime della frequenza di taglio")
gf.display_dizionario(dizionario_f_taglio)
# Out:
# Stime della frequenza di taglio
# <table border="1" style="border-collapse: collapse;"><tr><td><strong>locale_A</strong></td><td>5535.78019410429 ± 670.926935521037</td></tr><tr><td><strong>locale_phi</strong></td><td>3043.4772154952693 ± 163.50102979361537</td></tr><tr><td><strong>nonlineare_A</strong></td><td>5471.993795836486 ± 128.713955153682</td></tr><tr><td><strong>nonlineare_phi</strong></td><td>5600.994881247422 ± 0.15931596283440966</td></tr><tr><td><strong>bode</strong></td><td>5200.050002138249 ± 0.9999999992923402</td></tr><tr><td><strong>linearizzato_A</strong></td><td>3790.487952486969 ± 221.00579955882003</td></tr><tr><td><strong>linearizzato_phi</strong></td><td>-5861.9314221443265 ± 99.23490940849138</td></tr></table>

# %%
print("Chi quadro ridotto relativo al fit di ciascuna stima")
gf.display_dizionario(dizionario_chi)
# Out:
# Chi quadro ridotto relativo al fit di ciascuna stima
# <table border="1" style="border-collapse: collapse;"><tr><td><strong>locale_A</strong></td><td>0.05876410291631806</td></tr><tr><td><strong>locale_phi</strong></td><td>3.658122411280301</td></tr><tr><td><strong>nonlineare_A</strong></td><td>0.006204195897804171</td></tr><tr><td><strong>nonlineare_phi</strong></td><td>3.7248286604533036</td></tr><tr><td><strong>bode</strong></td><td>0.013347464501414458</td></tr><tr><td><strong>linearizzato_A</strong></td><td>3.37791908728815</td></tr><tr><td><strong>linearizzato_phi</strong></td><td>2.5053820595301044</td></tr></table>
