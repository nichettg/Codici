# %%
import sys
sys.path.append("..")

# %run "../moduli.py"

# %%
keys = ["modello_A", "modello_B"]

# %%
def modello_A(par, x):
    return par[0] + par[1]*x + par[2]*x**2

def modello_B(par, x):
    return par[0] + par[1]*x

modelli = {
    keys[0] : modello_A,
    keys[1] : modello_B,
}

parametri_labels = {
    keys[0] : ['a', 'b', 'c'],
    keys[1] : ['a', 'b'],
}

beta = {
    keys[0] : [1, 1, 1],
    keys[1] : [0, 1],
}

cartella_output = "confronto"

# %% [markdown]
# # Analisi Singola

# %%
for key in keys:
    risultati = analizza(key, modelli[key], parametri_labels[key], beta[key])

# %% [markdown]
# # 1. Lettura

# %% [markdown]
# Lettura dal file "config.json".

# %%
files_input = {}
dict_json = {}

for key in keys:
    with open(key + ".json") as f:
        nomi = json.load(f)
    dict_json[key] = nomi
    files_input[key] = os.path.join(nomi["cartella"],nomi["file_input"])

# %% [markdown]
# Creazione cartelle

# %%
os.makedirs(cartella_output, exist_ok=True)
for key in keys:
    os.makedirs(os.path.join("confronto",key),
                exist_ok=True
    )

# %% [markdown]
# Lettura file dati

# %%
data = {}

for key in keys:
    data[key] = {}
    dati = let.csv_to_dict(files_input[key])

    xdata = Misura(dati["x"],dati["sx"])
    ydata = Misura(dati["y"],dati["sy"])

    data[key]['x'] = xdata
    data[key]['y'] = ydata

# %% [markdown]
# # 2. Analisi

# %% [markdown]
# Analisi e test statistici

# %%
analisi = {}
residui = {}
chi_quadri = {}

for key in keys:

    ###########################
    ##  Lettura
    ###########################

    xdata = data[key]["x"]
    ydata = data[key]["y"]
    modello = modelli[key]
    beta0 = beta[key]

    param_labels = parametri_labels[key]
    titolo = f"{dict_json[key]['titolo']}"

    file_output1 = os.path.join(
        cartella_output,
        key,
        dict_json[key]["output"]["regressione"] + ".txt"
    )
    file_output2 = os.path.join(
        cartella_output,
        key,
        dict_json[key]["output"]["residui"] + ".txt"
    )
    file_output3 = os.path.join(
        cartella_output,
        key,
        dict_json[key]["output"]["chi"] + ".txt"
    )

    ###########################
    ##  Analisi
    ###########################

    anal = an.fit(xdata, ydata, modello, beta0)
    analisi[key] = anal
    let.inizializza_output(file_output1)
    let.salva_analisi(anal, param_labels, file_output1)

    ###########################
    ##  Test Statistici
    ###########################
    # Residui
    let.inizializza_output(file_output2)
    res = an.residui(xdata, ydata, anal.val, modello, file_output2, titolo)
    residui[key] = res

    # Chi
    let.inizializza_output(file_output3)
    chi = an.chi_quadro(xdata, ydata, anal.val, modello, file_output3, titolo)
    chi_quadri[key] = chi

    print(f"###### {key} ######")
    print(RisultatiFit(anal,res,chi))

    # Rimozione file e cartella di log delle analisi perchè
    # già create separatamente (fuori dalla cartella confronto) con l'analisi singola.
    os.remove(file_output1)
    os.remove(file_output2)
    os.remove(file_output3)
    os.rmdir(cartella_output + "/" + key)
# Out:
# ###### modello_A ######
# Parametri regressione :
# 1.0208364461380757 ± 0.1077977104028583
# 0.4844121135578953 ± 0.05014740416748728
# 0.08072242276881095 ± 0.0048295464076453885
#
# Somma residui :
# 0.0000
# Somma chi quadri e chi ridotto :
# 3.7955
# 0.4744
#
# ###### modello_B ######
# Parametri regressione :
# 1.0163636238734415 ± 0.06234070601905883
# 1.0196969698015905 ± 0.011677484149749316
#
# Somma residui :
# 0.0000
# Somma chi quadri e chi ridotto :
# 3.5663
# 0.4458

# %% [markdown]
# # 3. Grafici

# %% [markdown]
# ## Regressione

# %%
titolo = rf"{dict_json[keys[0]]['titolo']}" + "".join(rf", {dict_json[keys[i+1]]['titolo']}" for i in range(len(keys)-1))
xlabel = rf"{dict_json[keys[0]]['xlabel']}" + "".join(rf",\;{dict_json[keys[i+1]]['xlabel']}" for i in range(len(keys)-1))
xunit = rf"{dict_json[keys[0]]['xunit']}" + "".join(rf",\;{dict_json[keys[i+1]]['xunit']}" for i in range(len(keys)-1))
ylabel = rf"{dict_json[keys[0]]['ylabel']}" + "".join(rf",\;{dict_json[keys[i+1]]['ylabel']}" for i in range(len(keys)-1))
yunit = rf"{dict_json[keys[0]]['yunit']}" + "".join(rf",\;{dict_json[keys[i+1]]['yunit']}" for i in range(len(keys)-1))

file_output1 = os.path.join(
    cartella_output,
    dict_json[key]["output"]["regressione"] + ".pdf"
)
file_output2 = os.path.join(
    cartella_output,
    dict_json[key]["output"]["chi"] + ".pdf"
)

# Inizializzazione e labels
fig1, (ax1, ax2) = plt.subplots(
    2, 1,
    figsize=(10, 8),
    gridspec_kw={'height_ratios': [5, 3]},
    constrained_layout=True,
    sharex=True
)
ax1.tick_params(axis='x', labelbottom=False)
gf.parametri_grafico(ax1, f"{titolo}", ylabel= rf"${ylabel}\quad [{yunit}]$")
gf.parametri_grafico(ax2, xlabel=rf"${xlabel}\quad [{xunit}]$", ylabel="Residui")

fig2,ax = plt.subplots(1, 1,  figsize=(10, 3), constrained_layout = True)
gf.parametri_grafico(ax, xlabel=rf"${xlabel}\quad [{xunit}]$", ylabel=r"$\chi^2$")

for j,key in enumerate(keys):

    ###########################
    ##  Lettura
    ###########################

    xdata = data[key]["x"]
    ydata =  data[key]["y"]
    anal = analisi[key]
    modello = modelli[key]
    res = residui[key]
    chi = chi_quadri[key]

    param_labels = parametri_labels[key]

    ###########################
    ##  Plotting Regressione
    ###########################

    # Dati
    ax1.errorbar(
        xdata.val,
        ydata.val,
        xerr=xdata.s,
        yerr=ydata.s,
        label=f"Dati {dict_json[key]['titolo']}",
        **gf.errorbar_params,
        color = gf.colori[j]
    )

    # Fit
    fit_label = f"Fit {dict_json[key]['titolo']}:" + "\n" + "".join(rf"${param_labels[i]}$=${gf.formatta_errore(anal.val[i],anal.s[i])}$" + "\n"  for i in range(len(param_labels)))
    x_fit = np.linspace(min(xdata.val), max(xdata.val), 500)
    ax1.plot(
        x_fit,
        modello(anal.val,x_fit),
        label=fit_label,
        **gf.plot_params,
        color = gf.darken(gf.colori[j])
    )

    ax1.legend()

    # Residui
    ax2.errorbar(
        res[0],
        res[1],
        yerr=res[2],
        **gf.errorbar_params,
        color=gf.colori[j]
    )
    # Linea orizzontale
    ax2.axhline(
        0,
        **gf.line_params,
        color="red"
    )

    ###########################
    ##  Plotting Chi Quadri
    ###########################

    # Chi Quadri
    ax.errorbar(
        chi[0],
        chi[1],
        yerr=chi[2],
        **gf.errorbar_params,
        color=gf.colori[j]
    )

    # Linea orizzontale
    ax.axhline(
        0,
        **gf.line_params,
        color="red"
    )

let.salva_grafico(fig1,file_output1)
let.salva_grafico(fig2, file_output2)
