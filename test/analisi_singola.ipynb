# %%
import sys
sys.path.append("..")

# %run "../moduli.py"

# %%
nome = "modello_A"

# %%
def modello(par,x):
    return par[0] + par[1]*x + par[2]*x**2

param_labels = ["a", "b", "c"]

beta0 = [0, 1, 0]

# %%
risultati = analizza(nome, modello, param_labels, beta0)

# %%
print(risultati)
# Out:
# Parametri regressione :
# 1.0208364452064742 ± 0.10774224616614572
# 0.4844121158603123 ± 0.05012804096430595
# 0.08072242250914108 ± 0.004828045473512349
#
# Somma residui :
# 0.0000
# Somma chi quadri e chi ridotto :
# 3.7955
# 0.4744

# %%
par = risultati.anal[0]
spar = risultati.anal[1]

parametri_profilazione = [[par[0], par[1], par[2]], [spar[0], spar[1], spar[2]]]
let.esporta_pickle(parametri_profilazione, nome + ".pkl")
